# %%
# !pip install transformers[torch] accelerate
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.26.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.1)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.1.0+cu121)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers[torch]) (1.3.0)

# %%
import os
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

from transformers import AutoImageProcessor, AutoModelForImageClassification
from PIL import Image
import requests

import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
from torchvision.io import read_image
from transformers import TrainingArguments, Trainer, MobileNetV2Config
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class CustomImageDataset(Dataset):
   # Inicjalizacja zestawu danych z katalogiem obrazów, procesorem i etykietami
    def __init__(self, img_dir, processor, labels):
        self.img_dir = img_dir
        self.img_labels = labels
        self.processor = processor

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):

        # Pobranie ścieżki do obrazu dla danego indeksu
        img_path = os.path.join(self.img_dir, self.img_labels[idx][0])
        # Wczytanie obrazu za pomocą funkcji read_image
        image = read_image(img_path)
        # Przetworzenie obrazu za pomocą określonego procesora i zwrócenie go jako tensory PyTorch. Tensory to struktury danych do przechowywania i przetwarzania danych numerycznych.
        processed = self.processor(images=image, return_tensors='pt')
        # Wyodrębnienie etykiety z zestawu danych i przekształcenie jej w tensor PyTorch
        label = torch.tensor(self.img_labels[idx][1])
        # Zwrócenie słownika zawierającego przetworzony obraz jako 'pixel_values' i etykietę jako 'labels'
        return {'pixel_values': processed['pixel_values'].squeeze(), 'labels': label}

# %%
# Lista klas reprezentujących figury szachowe
class_names =  ['Rook', 'Queen','Pawn','Knight','King','Bishop']

# Słownik mapujący nazwy klas na ich odpowiadające indeksy
label_map = {class_name: i for i, class_name in enumerate(class_names)}

# %%
# Klasy oraz przypisane im indeksy
label_map
# Out:
# {'Rook': 0, 'Queen': 1, 'Pawn': 2, 'Knight': 3, 'King': 4, 'Bishop': 5}

# %%
# Katalog zawierający dane treningowe
img_dir = '/content/drive/MyDrive/Chess/Train'
# Pusta lista, która będzie przechowywać etykiety obrazów
img_labels = []

# Iteracja po słowniku label_map (nazwa klasy, indeks klasy)
for class_name, class_idx in label_map.items():
  # Ścieżka do katalogu z obrazami danej klasy
  class_dir = os.path.join(img_dir, class_name)
  # Iteracja po plikach obrazów w katalogu danej klasy
  for img_name in os.listdir(class_dir):
    # Dodanie krotki do listy img_labels zawierającej ścieżkę do obrazu i indeks klasy
    img_labels.append((os.path.join(class_name, img_name), class_idx))

# %%
# Katalogi klas z przypisanymi indeksami
img_labels
# Out:
# [('Rook/00000035.jpg', 0),
#  ('Rook/00000102.jpg', 0),
#  ('Rook/00000075.jpg', 0),
#  ('Rook/00000066.png', 0),
#  ('Rook/00000021.jpg', 0),
#  ('Rook/00000058.jpg', 0),
#  ('Rook/00000015.jpg', 0),
#  ('Rook/00000098.png', 0),
#  ('Rook/00000044.jpg', 0),
#  ('Rook/00000083.jpg', 0),
#  ('Rook/00000020.jpg', 0),
#  ('Rook/00000112.jpg', 0),
#  ('Rook/00000099.jpg', 0),
#  ('Rook/00000171.jpg', 0),
#  ('Rook/00000031.jpg', 0),
#  ('Rook/00000064.png', 0),
#  ('Rook/00000063.jpg', 0),
#  ('Rook/00000121.jpg', 0),
#  ('Rook/00000117.jpg', 0),
#  ('Rook/00000059.jpg', 0),
#  ('Rook/00000056.png', 0),
#  ('Rook/00000168.jpg', 0),
#  ('Rook/00000016.jpg', 0),
#  ('Rook/00000046.jpg', 0),
#  ('Rook/00000026.png', 0),
#  ('Rook/00000120.jpg', 0),
#  ('Rook/00000142.jpg', 0),
#  ('Rook/00000086.jpg', 0),
#  ('Rook/00000107.jpg', 0),
#  ('Rook/00000017.jpg', 0),
#  ('Rook/00000022.jpg', 0),
#  ('Rook/00000118.jpg', 0),
#  ('Rook/00000034.jpg', 0),
#  ('Rook/00000004.jpg', 0),
#  ('Rook/00000054.jpg', 0),
#  ('Rook/00000084.png', 0),
#  ('Rook/00000180.jpg', 0),
#  ('Rook/00000130.jpeg', 0),
#  ('Rook/00000147.jpg', 0),
#  ('Rook/00000125.jpg', 0),
#  ('Rook/00000011.jpg', 0),
#  ('Rook/00000005.jpg', 0),
#  ('Rook/00000085.png', 0),
#  ('Rook/00000051.jpg', 0),
#  ('Rook/00000033.jpg', 0),
#  ('Rook/00000088.jpg', 0),
#  ('Rook/00000136.jpg', 0),
#  ('Rook/00000018.jpg', 0),
#  ('Rook/00000101.jpg', 0),
#  ('Rook/00000073.jpg', 0),
#  ('Rook/00000045.jpg', 0),
#  ('Rook/00000049.jpg', 0),
#  ('Rook/00000065.jpg', 0),
#  ('Rook/00000124.png', 0),
#  ('Rook/00000024.jpg', 0),
#  ('Rook/00000079.jpg', 0),
#  ('Rook/00000076.jpg', 0),
#  ('Rook/00000006.jpg', 0),
#  ('Rook/00000179.png', 0),
#  ('Rook/00000053.jpg', 0),
#  ('Rook/00000072.jpg', 0),
#  ('Rook/00000159.jpg', 0),
#  ('Rook/00000163.jpg', 0),
#  ('Rook/00000014.jpg', 0),
#  ('Rook/00000197.jpg', 0),
#  ('Rook/00000160.jpg', 0),
#  ('Rook/00000145.jpg', 0),
#  ('Rook/00000003.JPG', 0),
#  ('Rook/00000185.jpg', 0),
#  ('Rook/00000019.jpg', 0),
#  ('Rook/00000032.jpg', 0),
#  ('Rook/00000119.jpg', 0),
#  ('Rook/00000113.jpg', 0),
#  ('Rook/00000132.jpg', 0),
#  ('Rook/00000135.jpg', 0),
#  ('Rook/00000038.jpg', 0),
#  ('Rook/00000095.jpg', 0),
#  ('Rook/00000071.jpg', 0),
#  ('Rook/00000103.png', 0),
#  ('Rook/00000050.jpg', 0),
#  ('Rook/00000008.jpg', 0),
#  ('Rook/00000077.jpg', 0),
#  ('Rook/00000061.jpg', 0),
#  ('Rook/00000025.jpeg', 0),
#  ('Rook/00000082.jpg', 0),
#  ('Rook/00000189.jpg', 0),
#  ('Rook/00000195.jpg', 0),
#  ('Rook/00000165.jpg', 0),
#  ('Rook/00000028.jpg', 0),
#  ('Rook/00000002.JPG', 0),
#  ('Rook/00000027.jpg', 0),
#  ('Rook/00000184.jpg', 0),
#  ('Rook/00000007.jpg', 0),
#  ('Rook/00000131.jpg', 0),
#  ('Rook/00000116.jpg', 0),
#  ('Rook/00000177.JPG', 0),
#  ('Rook/00000164.jpg', 0),
#  ('Rook/00000114.jpg', 0),
#  ('Rook/00000074.jpg', 0),
#  ('Rook/00000010.jpg', 0),
#  ('Rook/00000127.jpg', 0),
#  ('Rook/00000097.jpg', 0),
#  ('Rook/00000074_resized.jpg', 0),
#  ('Rook/00000206_resized.jpg', 0),
#  ('Rook/00000097_resized.jpg', 0),
#  ('Rook/00000113_resized.jpg', 0),
#  ('Rook/00000028_resized.jpg', 0),
#  ('Rook/00000011_resized.jpg', 0),
#  ('Rook/00000130_resized.jpg', 0),
#  ('Rook/00000012_resized.jpg', 0),
#  ('Rook/00000046_resized.jpg', 0),
#  ('Rook/00000216_resized.jpg', 0),
#  ('Rook/00000190_resized.jpg', 0),
#  ('Rook/00000148_resized.jpg', 0),
#  ('Rook/00000002_resized.jpg', 0),
#  ('Rook/00000155_resized.jpg', 0),
#  ('Rook/00000022_resized.jpg', 0),
#  ('Rook/00000084_resized.jpg', 0),
#  ('Rook/00000255_resized.jpg', 0),
#  ('Rook/00000088_resized.jpg', 0),
#  ('Rook/00000257_resized.jpg', 0),
#  ('Rook/00000181_resized.jpg', 0),
#  ('Rook/00000249_resized.jpg', 0),
#  ('Rook/00000082_resized.jpg', 0),
#  ('Rook/00000218_resized.jpg', 0),
#  ('Rook/00000109_resized.jpg', 0),
#  ('Rook/00000276_resized.jpg', 0),
#  ('Rook/00000117_resized.jpg', 0),
#  ('Rook/00000091_resized.jpg', 0),
#  ('Rook/00000119_resized.jpg', 0),
#  ('Rook/00000215_resized.jpg', 0),
#  ('Rook/00000264_resized.jpg', 0),
#  ('Rook/00000049_resized.jpg', 0),
#  ('Rook/00000147_resized.jpg', 0),
#  ('Rook/00000034_resized.jpg', 0),
#  ('Rook/00000207_resized.jpg', 0),
#  ('Rook/00000221_resized.jpg', 0),
#  ('Rook/00000168_resized.jpg', 0),
#  ('Rook/00000150_resized.jpg', 0),
#  ('Rook/00000063_resized.jpg', 0),
#  ('Rook/00000185_resized.jpg', 0),
#  ('Rook/00000043_resized.jpg', 0),
#  ('Rook/00000172_resized.jpg', 0),
#  ('Rook/00000144_resized.jpg', 0),
#  ('Rook/00000008_resized.jpg', 0),
#  ('Rook/00000166_resized.jpg', 0),
#  ('Rook/00000081_resized.jpg', 0),
#  ('Rook/00000131_resized.jpg', 0),
#  ('Rook/00000292_resized.jpg', 0),
#  ('Rook/00000254_resized.jpg', 0),
#  ('Rook/00000138_resized.jpg', 0),
#  ('Rook/00000236_resized.jpg', 0),
#  ('Rook/00000035_resized.jpg', 0),
#  ('Rook/00000092_resized.jpg', 0),
#  ('Rook/00000096_resized.jpg', 0),
#  ('Rook/00000075_resized.jpg', 0),
#  ('Rook/00000163_resized.jpg', 0),
#  ('Rook/00000013_resized.jpg', 0),
#  ('Rook/00000005_resized.jpg', 0),
#  ('Rook/00000059_resized.jpg', 0),
#  ('Rook/00000104_resized.jpg', 0),
#  ('Rook/00000267_resized.jpg', 0),
#  ('Rook/00000210_resized.jpg', 0),
#  ('Rook/00000161_resized.jpg', 0),
#  ('Rook/00000137_resized.jpg', 0),
#  ('Rook/00000044_resized.jpg', 0),
#  ('Rook/00000078_resized.jpg', 0),
#  ('Rook/00000093_resized.jpg', 0),
#  ('Rook/00000103_resized.jpg', 0),
#  ('Rook/00000004_resized.jpg', 0),
#  ('Rook/00000135_resized.jpg', 0),
#  ('Rook/00000076_resized.jpg', 0),
#  ('Rook/00000120_resized.jpg', 0),
#  ('Rook/00000159_resized.jpg', 0),
#  ('Rook/00000140_resized.jpg', 0),
#  ('Rook/00000220_resized.jpg', 0),
#  ('Rook/00000115_resized.jpg', 0),
#  ('Rook/00000030_resized.jpg', 0),
#  ('Rook/00000089_resized.jpg', 0),
#  ('Rook/00000053_resized.jpg', 0),
#  ('Rook/00000006_resized.jpg', 0),
#  ('Rook/00000045_resized.jpg', 0),
#  ('Rook/00000133_resized.jpg', 0),
#  ('Rook/00000079_resized.jpg', 0),
#  ('Rook/00000202_resized.jpg', 0),
#  ('Rook/00000156_resized.jpg', 0),
#  ('Rook/00000037_resized.jpg', 0),
#  ('Rook/00000047_resized.jpg', 0),
#  ('Rook/00000067_resized.jpg', 0),
#  ('Rook/00000228_resized.jpg', 0),
#  ('Rook/00000204_resized.jpg', 0),
#  ('Rook/00000243_resized.jpg', 0),
#  ('Rook/00000127_resized.jpg', 0),
#  ('Rook/00000240_resized.jpg', 0),
#  ('Rook/00000039_resized.jpg', 0),
#  ('Rook/00000068_resized.jpg', 0),
#  ('Rook/00000010_resized.jpg', 0),
#  ('Rook/00000073_resized.jpg', 0),
#  ('Rook/00000250_resized.jpg', 0),
#  ('Rook/00000061_resized.jpg', 0),
#  ('Rook/00000029_resized.jpg', 0),
#  ('Rook/00000014_resized.jpg', 0),
#  ('Rook/00000023_resized.jpg', 0),
#  ('Rook/00000211_resized.jpg', 0),
#  ('Rook/00000050_resized.jpg', 0),
#  ('Rook/00000098_resized.jpg', 0),
#  ('Rook/00000125_resized.jpg', 0),
#  ('Rook/00000054_resized.jpg', 0),
#  ('Rook/00000242_resized.jpg', 0),
#  ('Rook/00000031_resized.jpg', 0),
#  ('Rook/00000027_resized.jpg', 0),
#  ('Rook/00000265_resized.jpg', 0),
#  ('Rook/00000025_resized.jpg', 0),
#  ('Rook/00000007_resized.jpg', 0),
#  ('Rook/00000019_resized.jpg', 0),
#  ('Rook/00000001_resized.jpg', 0),
#  ('Rook/00000017_resized.jpg', 0),
#  ('Rook/00000026_resized.jpg', 0),
#  ('Rook/00000261_resized.jpg', 0),
#  ('Rook/00000258_resized.jpg', 0),
#  ('Rook/00000142_resized.jpg', 0),
#  ('Rook/00000136_resized.jpg', 0),
#  ('Rook/00000077_resized.jpg', 0),
#  ('Rook/00000139_resized.jpg', 0),
#  ('Rook/00000191_resized.jpg', 0),
#  ('Queen/00000119.jpg', 1),
#  ('Queen/00000094.jpg', 1),
#  ('Queen/00000032.jpeg', 1),
#  ('Queen/00000219.jpg', 1),
#  ('Queen/00000006.jpg', 1),
#  ('Queen/00000014.jpg', 1),
#  ('Queen/00000068.png', 1),
#  ('Queen/00000204.jpg', 1),
#  ('Queen/00000199.jpg', 1),
#  ('Queen/00000021.jpg', 1),
#  ('Queen/00000127.jpg', 1),
#  ('Queen/00000043.jpg', 1),
#  ('Queen/00000182.jpg', 1),
#  ('Queen/00000040.jpg', 1),
#  ('Queen/00000132_resized.jpg', 1),
#  ('Queen/00000185_resized.jpg', 1),
#  ('Queen/00000275_resized.jpg', 1),
#  ('Queen/00000048_resized.jpg', 1),
#  ('Queen/00000138_resized.jpg', 1),
#  ('Queen/00000021_resized.jpg', 1),
#  ('Queen/00000100_resized.jpg', 1),
#  ('Queen/00000170_resized.jpg', 1),
#  ('Queen/00000210_resized.jpg', 1),
#  ('Queen/00000168_resized.jpg', 1),
#  ('Queen/00000010_resized.jpg', 1),
#  ('Queen/00000266_resized.jpg', 1),
#  ('Queen/00000097_resized.jpg', 1),
#  ('Queen/00000109_resized.jpg', 1),
#  ('Queen/00000051_resized.jpg', 1),
#  ('Queen/00000122_resized.jpg', 1),
#  ('Queen/00000133_resized.jpg', 1),
#  ('Queen/00000151_resized.jpg', 1),
#  ('Queen/00000112_resized.jpg', 1),
#  ('Queen/00000050_resized.jpg', 1),
#  ('Queen/00000068_resized.jpg', 1),
#  ('Queen/00000022_resized.jpg', 1),
#  ('Queen/00000220_resized.jpg', 1),
#  ('Queen/00000134_resized.jpg', 1),
#  ('Queen/00000280_resized.jpg', 1),
#  ('Queen/00000054_resized.jpg', 1),
#  ('Queen/00000158_resized.jpg', 1),
#  ('Queen/00000017_resized.jpg', 1),
#  ('Queen/00000014_resized.jpg', 1),
#  ('Queen/00000106_resized.jpg', 1),
#  ('Queen/00000061_resized.jpg', 1),
#  ('Queen/00000044_resized.jpg', 1),
#  ('Queen/00000154_resized.jpg', 1),
#  ('Queen/00000079_resized.jpg', 1),
#  ('Queen/00000148_resized.jpg', 1),
#  ('Queen/00000157_resized.jpg', 1),
#  ('Queen/00000119_resized.jpg', 1),
#  ('Queen/00000052_resized.jpg', 1),
#  ('Queen/00000200_resized.jpg', 1),
#  ('Queen/00000088_resized.jpg', 1),
#  ('Queen/00000091_resized.jpg', 1),
#  ('Queen/00000124_resized.jpg', 1),
#  ('Queen/00000034_resized.jpg', 1),
#  ('Queen/00000058_resized.jpg', 1),
#  ('Queen/00000272_resized.jpg', 1),
#  ('Queen/00000012_resized.jpg', 1),
#  ('Queen/00000011_resized.jpg', 1),
#  ('Queen/00000000_resized.jpg', 1),
#  ('Queen/00000095_resized.jpg', 1),
#  ('Queen/00000075_resized.jpg', 1),
#  ('Queen/00000001_resized.jpg', 1),
#  ('Queen/00000269_resized.jpg', 1),
#  ('Queen/00000063_resized.jpg', 1),
#  ('Queen/00000213_resized.jpg', 1),
#  ('Queen/00000131_resized.jpg', 1),
#  ('Queen/00000055_resized.jpg', 1),
#  ('Queen/00000069_resized.jpg', 1),
#  ('Queen/00000228_resized.jpg', 1),
#  ('Queen/00000187_resized.jpg', 1),
#  ('Queen/00000007_resized.jpg', 1),
#  ('Queen/00000057_resized.jpg', 1),
#  ('Queen/00000065_resized.jpg', 1),
#  ('Queen/00000165_resized.jpg', 1),
#  ('Queen/00000104_resized.jpg', 1),
#  ('Queen/00000084_resized.jpg', 1),
#  ('Queen/00000221_resized.jpg', 1),
#  ('Queen/00000146_resized.jpg', 1),
#  ('Queen/00000090_resized.jpg', 1),
#  ('Queen/00000284_resized.jpg', 1),
#  ('Queen/00000217_resized.jpg', 1),
#  ('Queen/00000121_resized.jpg', 1),
#  ('Queen/00000199_resized.jpg', 1),
#  ('Queen/00000102_resized.jpg', 1),
#  ('Queen/00000218_resized.jpg', 1),
#  ('Queen/00000167_resized.jpg', 1),
#  ('Queen/00000032_resized.jpg', 1),
#  ('Queen/00000030_resized.jpg', 1),
#  ('Queen/00000231_resized.jpg', 1),
#  ('Queen/00000152_resized.jpg', 1),
#  ('Queen/00000094_resized.jpg', 1),
#  ('Queen/00000128_resized.jpg', 1),
#  ('Queen/00000201_resized.jpg', 1),
#  ('Queen/00000175_resized.jpg', 1),
#  ('Queen/00000140_resized.jpg', 1),
#  ('Queen/00000206_resized.jpg', 1),
#  ('Queen/00000208_resized.jpg', 1),
#  ('Queen/00000126_resized.jpg', 1),
#  ('Queen/00000214_resized.jpg', 1),
#  ('Queen/00000039_resized.jpg', 1),
#  ('Queen/00000060_resized.jpg', 1),
#  ('Queen/00000004_resized.jpg', 1),
#  ('Queen/00000076_resized.jpg', 1),
#  ('Queen/00000125_resized.jpg', 1),
#  ('Queen/00000166_resized.jpg', 1),
#  ('Queen/00000043_resized.jpg', 1),
#  ('Queen/00000123_resized.jpg', 1),
#  ('Queen/00000247_resized.jpg', 1),
#  ('Queen/00000042_resized.jpg', 1),
#  ('Queen/00000153_resized.jpg', 1),
#  ('Queen/00000238_resized.jpg', 1),
#  ('Queen/00000005_resized.jpg', 1),
#  ('Queen/00000013_resized.jpg', 1),
#  ('Queen/00000086_resized.jpg', 1),
#  ('Queen/00000047_resized.jpg', 1),
#  ('Queen/00000161_resized.jpg', 1),
#  ('Queen/00000008_resized.jpg', 1),
#  ('Queen/00000077_resized.jpg', 1),
#  ('Queen/00000181_resized.jpg', 1),
#  ('Queen/00000003_resized.jpg', 1),
#  ('Queen/00000258_resized.jpg', 1),
#  ('Pawn/00000058.jpg', 2),
#  ('Pawn/00000079.jpg', 2),
#  ('Pawn/00000099.jpg', 2),
#  ('Pawn/00000110.jpg', 2),
#  ('Pawn/00000070.jpg', 2),
#  ('Pawn/00000028.jpg', 2),
#  ('Pawn/00000022.jpg', 2),
#  ('Pawn/00000017.jpg', 2),
#  ('Pawn/00000080.png', 2),
#  ('Pawn/00000074.jpg', 2),
#  ('Pawn/00000042.png', 2),
#  ('Pawn/00000007.jpg', 2),
#  ('Pawn/00000084.jpg', 2),
#  ('Pawn/00000015.png', 2),
#  ('Pawn/00000032.jpg', 2),
#  ('Pawn/00000114.jpg', 2),
#  ('Pawn/00000020.jpg', 2),
#  ('Pawn/00000037.jpeg', 2),
#  ('Pawn/00000014.png', 2),
#  ('Pawn/00000013.jpg', 2),
#  ('Pawn/00000109.jpg', 2),
#  ('Pawn/00000010.jpg', 2),
#  ('Pawn/00000039.jpg', 2),
#  ('Pawn/00000027.png', 2),
#  ('Pawn/00000048.jpg', 2),
#  ('Pawn/00000000.jpg', 2),
#  ('Pawn/00000033.jpg', 2),
#  ('Pawn/00000005.jpg', 2),
#  ('Pawn/00000060.jpg', 2),
#  ('Pawn/00000019.jpg', 2),
#  ('Pawn/00000115.jpg', 2),
#  ('Pawn/00000119.png', 2),
#  ('Pawn/00000073.jpg', 2),
#  ('Pawn/00000057.jpg', 2),
#  ('Pawn/00000078.jpg', 2),
#  ('Pawn/00000035.jpg', 2),
#  ('Pawn/00000106.png', 2),
#  ('Pawn/00000059.jpg', 2),
#  ('Pawn/00000043.jpg', 2),
#  ('Pawn/00000025.png', 2),
#  ('Pawn/00000049.png', 2),
#  ('Pawn/00000107.jpg', 2),
#  ('Pawn/00000085.jpg', 2),
#  ('Pawn/00000083.jpg', 2),
#  ('Pawn/00000069.jpg', 2),
#  ('Pawn/00000012.jpg', 2),
#  ('Pawn/00000111.jpg', 2),
#  ('Pawn/00000029.jpg', 2),
#  ('Pawn/00000082.jpg', 2),
#  ('Pawn/00000002.jpg', 2),
#  ('Pawn/00000072.jpg', 2),
#  ('Pawn/00000031.jpg', 2),
#  ('Pawn/00000112.jpg', 2),
#  ('Pawn/00000056.JPG', 2),
#  ('Pawn/00000116.jpg', 2),
#  ('Pawn/00000117.jpg', 2),
#  ('Pawn/00000004.jpg', 2),
#  ('Pawn/00000026.jpg', 2),
#  ('Pawn/00000011.jpg', 2),
#  ('Pawn/00000055.jpg', 2),
#  ('Pawn/00000071.jpg', 2),
#  ('Pawn/00000041.jpg', 2),
#  ('Pawn/00000067.jpg', 2),
#  ('Pawn/00000063.jpg', 2),
#  ('Pawn/00000097.jpg', 2),
#  ('Pawn/00000016.jpg', 2),
#  ('Pawn/00000001.png', 2),
#  ('Pawn/00000139.jpg', 2),
#  ('Pawn/00000126.png', 2),
#  ('Pawn/00000170.jpg', 2),
#  ('Pawn/00000196.jpg', 2),
#  ('Pawn/00000182.jpg', 2),
#  ('Pawn/00000152.jpg', 2),
#  ('Pawn/00000163.png', 2),
#  ('Pawn/00000177.jpg', 2),
#  ('Pawn/00000151.png', 2),
#  ('Pawn/00000175.jpg', 2),
#  ('Pawn/00000166.jpg', 2),
#  ('Pawn/00000180.jpg', 2),
#  ('Pawn/00000171.jpg', 2),
#  ('Pawn/00000172.png', 2),
#  ('Pawn/00000140.jpg', 2),
#  ('Pawn/00000136.png', 2),
#  ('Pawn/00000121.jpg', 2),
#  ('Pawn/00000134.jpg', 2),
#  ('Pawn/00000176.jpg', 2),
#  ('Pawn/00000197.jpg', 2),
#  ('Bishop/00000001.jpg', 5),
#  ('Bishop/00000071.png', 5),
#  ('Bishop/00000006.jpg', 5),
#  ('Bishop/00000070.jpg', 5),
#  ('Bishop/00000074.jpg', 5),
#  ('Bishop/00000129.jpg', 5),
#  ('Bishop/00000112.jpg', 5),
#  ('Bishop/00000086.png', 5),
#  ('Bishop/00000012.jpg', 5),
#  ('Bishop/00000002.JPG', 5),
#  ('Bishop/00000117.jpg', 5),
#  ('Bishop/00000037.jpg', 5),
#  ('Bishop/00000114.jpg', 5),
#  ('Bishop/00000003.png', 5),
#  ('Bishop/00000020.jpg', 5),
#  ('Bishop/00000026.jpg', 5),
#  ('Bishop/00000004.jpg', 5),
#  ('Bishop/00000089.jpg', 5),
#  ('Bishop/00000102.jpg', 5),
#  ('Bishop/00000113.png', 5),
#  ('Bishop/00000075.jpg', 5),
#  ('Bishop/00000081.jpg', 5),
#  ('Bishop/00000088.jpg', 5),
#  ('Bishop/00000061.jpg', 5),
#  ('Bishop/00000031.jpg', 5),
#  ('Bishop/00000049.jpg', 5),
#  ('Bishop/00000008.jpg', 5),
#  ('Bishop/00000042.jpg', 5),
#  ('Bishop/00000054.jpeg', 5),
#  ('Bishop/00000025.jpg', 5),
#  ('Bishop/00000109.jpg', 5),
#  ('Bishop/00000034.jpg', 5),
#  ('Bishop/00000082.jpg', 5),
#  ('Bishop/00000092.jpg', 5),
#  ('Bishop/00000007.jpg', 5),
#  ('Bishop/00000120.jpg', 5),
#  ('Bishop/00000013.jpg', 5),
#  ('Bishop/00000094.jpg', 5),
#  ('Bishop/00000010.jpg', 5),
#  ('Bishop/00000079.jpg', 5),
#  ('Bishop/00000044.png', 5),
#  ('Bishop/00000177.jpg', 5),
#  ('Bishop/00000169.jpg', 5),
#  ('Bishop/00000130.png', 5),
#  ('Bishop/00000182.jpg', 5),
#  ('Bishop/00000192.jpg', 5),
#  ('Bishop/00000149.jpg', 5),
#  ('Bishop/00000136.png', 5),
#  ('Bishop/00000193.jpg', 5),
#  ('Bishop/00000189.jpg', 5),
#  ('Bishop/00000138.jpg', 5),
#  ('Bishop/00000188.jpg', 5),
#  ('Bishop/00000199.jpg', 5),
#  ...]

# %%
# Konfiguracja modelu MobileNetV2
config = MobileNetV2Config.from_pretrained('google/mobilenet_v2_1.0_224', num_labels=len(class_names))

# Mapowanie identyfikatorów klas na ich nazwy
config.id2label = {i: label for i, label in enumerate(class_names)}
# Mapowanie nazw klas na ich identyfikatory
config.label2id = {label: i for i, label in enumerate(class_names)}

# %%
# Tworzenie procesora obrazów
processor = AutoImageProcessor.from_pretrained("google/mobilenet_v2_1.0_224")
# Tworzenie modelu MobileNetV2 dla klasyfikacji obrazów
model = AutoModelForImageClassification.from_pretrained("google/mobilenet_v2_1.0_224", config=config, ignore_mismatched_sizes=True)
# Out:
# Some weights of MobileNetV2ForImageClassification were not initialized from the model checkpoint at google/mobilenet_v2_1.0_224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1001]) in the checkpoint and torch.Size([6]) in the model instantiated
# - classifier.weight: found shape torch.Size([1001, 1280]) in the checkpoint and torch.Size([6, 1280]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Tworzenie obiektu CustomImageDataset na podstawie zdefiniowanego img_dir, processor i img_labels
dataset = CustomImageDataset(img_dir, processor, img_labels)
# Tworzenie DataLoader do efektywnego przetwarzania danych treningowych w mini-batchach czyli podzbiorach danych treningowych, które są używane do aktualizacji wag modelu w procesie treningu.
data_loader = DataLoader(dataset, batch_size=2, shuffle=True)
# Konfiguracja argumentów treningowych
training_arg = TrainingArguments(output_dir='results', num_train_epochs = 7)
# Tworzenie obiektu Trainer do przeprowadzenia procesu treningu
trainer = Trainer(model=model, args=training_arg, train_dataset=dataset)

# %%
# Uruchamia proces treningu modelu
trainer.train()
# Out:
#     <div>
#
#       <progress value='1001' max='1001' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1001/1001 37:15, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.823000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.274300</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1001, training_loss=0.5482456025692609, metrics={'train_runtime': 2240.5914, 'train_samples_per_second': 3.568, 'train_steps_per_second': 0.447, 'total_flos': 1.6111681375297536e+16, 'train_loss': 0.5482456025692609, 'epoch': 7.0})

# %%
model.save_pretrained('model_finetuned')
config.save_pretrained('model_finetuned')

# %%
from sklearn.metrics import accuracy_score

# Ścieżka do katalogu z danymi testowymi
folder_path = '/content/drive/MyDrive/Chess/Test'

processor = AutoImageProcessor.from_pretrained('google/mobilenet_v2_1.0_224')
model = AutoModelForImageClassification.from_pretrained('model_finetuned')

# Listy przechowujące prawdziwe etykiety i przewidywane etykiety
true_labels = []
predicted_labels = []

# Lista przechowująca testowe straty
test_losses = []

# Iteracja po katalogach reprezentujących klasy w danych testowych
for class_dir in os.listdir(folder_path):
    class_path = os.path.join(folder_path, class_dir)
    if os.path.isdir(class_path):
        print(f"Przetwarzanie katalogu: {class_dir}")

        # Iteracja po plikach obrazów w katalogu danej klasy
        for image_file in os.listdir(class_path):
            if image_file.endswith(('.jpg', '.jpeg')):
                image_path = os.path.join(class_path, image_file)

                # Wczytanie obrazu i przetworzenie za pomocą procesora i modelu
                image = Image.open(image_path)
                inputs = processor(images=image, return_tensors="pt")
                outputs = model(**inputs)
                logits = outputs.logits
                predicted_class_idx = logits.argmax(-1).item()
                predicted_class = model.config.id2label[predicted_class_idx]

                # Pobranie prawdziwej etykiety z wcześniej utworzonego label_map
                true_label = label_map[class_dir]

                # Dodanie straty do listy
                loss = torch.nn.functional.cross_entropy(logits, torch.tensor([true_label]))
                test_losses.append(loss.item())

                # Aktualizacja list prawdziwych i przewidywanych etykiet
                true_labels.append(true_label)
                predicted_labels.append(predicted_class_idx)

                # Wyświetlenie obrazu z przewidzianą klasą
                plt.imshow(image)
                plt.title(predicted_class)
                plt.show()
                print(f"  Przewidziana klasa: {predicted_class}")

# Obliczenie dokładności
accuracy = accuracy_score(true_labels, predicted_labels)

# Obliczenie średniej testowej straty
average_test_loss = sum(test_losses) / len(test_losses) if len(test_losses) > 0 else 0.0

print("Accuracy:", accuracy)
print("Average Test Loss:", average_test_loss)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
